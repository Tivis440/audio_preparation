# %% [markdown]
# # Audio Preparation - Google Colab
#
# Автоматическое скачивание VoxForge, обработка аудио и генерация fake audio через TTS

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -q librosa soundfile numpy torch tqdm TTS requests beautifulsoup4 pandas scipy

# %%
# !git clone https://github.com/Tivis440/audio_preparation.git
# %cd audio_preparation

# %%
# !python main.py

# %%
import os
import pandas as pd

print('Real audio:', len(os.listdir('data/real')) if os.path.exists('data/real') else 0)
if os.path.exists('metadata.csv'):
    df = pd.read_csv('metadata.csv')
    print(f'Metadata: {len(df)} rows')
    print(df.head())

# %% [markdown]
# # Audio Preparation Colab
# VoxForge + TTS pipeline

# %%
# Setup and clone repo
# !pip install -q librosa soundfile numpy torch tqdm coqui-tts requests beautifulsoup4 pandas -U
# !git clone https://github.com/Tivis440/audio_preparation.git
# %cd audio_preparation

# %%
# Run pipeline
# !python main.py

# %%
# Check results
import os, pandas as pd
print('Real:', len(os.listdir('data/real')) if os.path.exists('data/real') else 0)
if os.path.exists('metadata.csv'):
    print(pd.read_csv('metadata.csv').head())

# %% [markdown]
# # Audio Preparation Colab
# VoxForge download and TTS generation

# %%
# Install dependencies
# !pip install -q librosa soundfile numpy requests beautifulsoup4 pandas -U
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu -q

# %%
# Clone and enter directory
# !git clone https://github.com/Tivis440/audio_preparation.git
# %cd audio_preparation

# %%
# Install coqui-tts (works with Python 3.12)
# !pip install -q 'coqui-tts[en]==0.22.0' -U 2>&1 | grep -i -E '(successfully|error:|warning:)' || true

# %%
# Run main script
# !python main.py

# %%
# View results
import os, pandas as pd
print('Real audio files:', len(os.listdir('data/real')) if os.path.exists('data/real') else 0)
if os.path.exists('metadata.csv'):
    df = pd.read_csv('metadata.csv')
    print(f'\nMetadata ({len(df)} rows):')
    print(df.head())
